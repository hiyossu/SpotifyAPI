# %%
from playlist_manager import combined_df
import pandas as pd

df = combined_df

df
# Out:
#                                  Track URI                   Track Name  \
# 0     spotify:track:1VvJjFZNhXkQQd5ILuNrXc                        Lucas
# 1     spotify:track:01iNOMVE89uKaurFTDZX2Y  homebdy (feat. Madman Stan)
# 2     spotify:track:0BgSx63sdmzqSsP4zEW9WI             Silent Treatment
# 3     spotify:track:0hr2Itwh84Zn3PiRRjHTnw                Gusto With Ya
# 4     spotify:track:6deBk1BSZkEO7WxvXKnqOZ                   Alam Ko Na
# ...                                    ...                          ...
# 6550  spotify:track:35fG1WDhAlSwPrEe6Qsv7w                  Velvet Rain
# 6552  spotify:track:3sdVGAht8fNfRSwkmschRo                Ocean Whisper
# 6554  spotify:track:3VrYr8AdaM5mlzs9UUA0Ef               Starlight Veil
# 6555  spotify:track:5J1xgWJidHK6ibhLAH3Ppt                  Amber Light
# 6556  spotify:track:0wAO9rTveOWkqP8NtIan0Z                  First Bloom
#
#                        Album Name Artist Name(s) Release Date  Duration (ms)  \
# ...

# %%
print(df['Tempo'].agg('mean'))
# Out:
# 118.13269201520912

# %%
# Out:
#                                        Track Name               Album Name
# 0     "Slut!" (Taylor's Version) (From The Vault)  1989 (Taylor's Version)
# 1                                         #Bad4Me                  #Bad4Me
# 2                                    $Hrimp Poboy                Gray/Grey
# 3                              $outh $ide $uicide       $outh $ide $uicide
# 4                                   $wag Princess            $wag Princess
# ...                                           ...                      ...
# 4731                                      조용히 다가와                나무 사이로 걷다
# 4732                                    푸른 바람 속으로               조용히 흐르는 시간
# 4733                                       하늘 아래서                나무 사이로 걷다
# 4734                                       하늘을 담다               조용히 흐르는 시간
# 4735                                    햇살이 머무는 곳                나무 사이로 걷다
#
# [4736 rows x 2 columns]
